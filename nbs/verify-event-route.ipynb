# %%
import requests

# %%
path = "/events"
base_url = "http://localhost:8000/api"
endpoint = f"{base_url}{path}"

# %%
response = requests.get(endpoint, json={"page": "about_page", "description": "This is aboutpage"})
print(response.headers)
response.text
# Out:
# {'date': 'Fri, 14 Aug 2026 07:25:09 GMT', 'server': 'uvicorn', 'content-length': '137', 'content-type': 'application/json'}
# '{"results":[{"page":"home_page","description":"This is homepage","id":1},{"page":"about_page","description":"This is aboutpage","id":2}]}'
