# %%
import requests

# %%
path = "/events"
base_url = "http://localhost:8000/api"
endpoint = f"{base_url}{path}"
print(endpoint)
# Out:
# http://localhost:8000/api/events

# %%
response = requests.post(endpoint, json={"page": "contact_page", "description": "This is contactpage"})
print(response.headers)
response.text
# Out:
# {'date': 'Sun, 16 Aug 2026 11:16:37 GMT', 'server': 'uvicorn', 'content-length': '109', 'content-type': 'application/json'}
# '{"created_at":"2026-08-16T11:16:37.904166Z","page":"contact_page","description":"This is contactpage","id":1}'
