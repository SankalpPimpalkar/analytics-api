# %%
import requests

# %%
path = "/events"
base_url = "http://localhost:8000/api"
endpoint = f"{base_url}{path}"

# %%
response = requests.post(endpoint, json={"id": 5, "page": "home_page"})
print(response.headers)
response.text
# Out:
# {'date': 'Wed, 12 Aug 2026 07:29:54 GMT', 'server': 'uvicorn', 'content-length': '27', 'content-type': 'application/json'}
# '{"id":5,"page":"home_page"}'
